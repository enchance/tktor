# %%
import os, asyncio, httpx, arrow, requests, time, hmac, hashlib
import pandas as pd
import pytz, time, httpx
from datetime import datetime as dt
from urllib.parse import urlencode
from binance import AsyncClient, BinanceSocketManager
from dotenv import load_dotenv
from nbclient.client import timestamp
from slugify import slugify
from sqlmodel import select

from exchange import Order, Wallet, Trade, ExchangeSvc
from authentication import AccountSvc
from core.config import get_session_context


load_dotenv('../../.env')
BINANCE_KEY = os.getenv('BINANCE_KEY')
BINANCE_SECRET = os.getenv('BINANCE_SECRET')

client = await AsyncClient.create(BINANCE_KEY, BINANCE_SECRET)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/aiohttp/connector.py:1115, in TCPConnector._wrap_create_connection(self, addr_infos, req, timeout, client_error, *args, **kwargs)
#    1112 async with ceil_timeout(
#    1113     timeout.sock_connect, ceil_threshold=timeout.ceil_threshold
#    1114 ):
# -> 1115     sock = await aiohappyeyeballs.start_connection(
#    1116         addr_infos=addr_infos,
#    1117         local_addr_infos=self._local_addr_infos,
#    1118         happy_eyeballs_delay=self._happy_eyeballs_delay,
#    1119         interleave=self._interleave,
#    1120         loop=self._loop,
#    1121     )
#    1122     return await self._loop.create_connection(*args, **kwargs, sock=sock)
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/aiohappyeyeballs/impl.py:122, in start_connection(addr_infos, local_addr_infos, happy_eyeballs_delay, interleave, loop, socket_factory)
#     121 if len(all_exceptions) == 1:
# --> 122     raise first_exception
#     123 else:
#     124     # If they all have the same str(), raise one.
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/aiohappyeyeballs/impl.py:73, in start_connection(addr_infos, local_addr_infos, happy_eyeballs_delay, interleave, loop, socket_factory)
#      72 try:
# ---> 73     sock = await _connect_sock(
#      74         current_loop,
#      75         exceptions,
#      76         addrinfo,
#      77         local_addr_infos,
#      78         None,
#      79         socket_factory,
#      80     )
#      81     break
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/aiohappyeyeballs/impl.py:208, in _connect_sock(loop, exceptions, addr_info, local_addr_infos, open_sockets, socket_factory)
#     207             raise OSError(f"no matching local address with {family=} found")
# --> 208 await loop.sock_connect(sock, address)
#     209 return sock
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/asyncio/selector_events.py:651, in BaseSelectorEventLoop.sock_connect(self, sock, address)
#     650 try:
# --> 651     return await fut
#     652 finally:
#     653     # Needed to break cycles when an exception occurs.
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/asyncio/selector_events.py:691, in BaseSelectorEventLoop._sock_connect_cb(self, fut, sock, address)
#     689     if err != 0:
#     690         # Jump to any except clause below.
# --> 691         raise OSError(err, f'Connect call failed {address}')
#     692 except (BlockingIOError, InterruptedError):
#     693     # socket is still registered, the callback will be retried later
#
# ConnectionRefusedError: [Errno 111] Connect call failed ('127.0.0.1', 443)
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorError                      Traceback (most recent call last)
# Cell In[1], line 21
#      18 BINANCE_KEY = os.getenv('BINANCE_KEY')
#      19 BINANCE_SECRET = os.getenv('BINANCE_SECRET')
# ---> 21 client = await AsyncClient.create(BINANCE_KEY, BINANCE_SECRET)
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/binance/async_client.py:82, in AsyncClient.create(cls, api_key, api_secret, requests_params, tld, base_endpoint, testnet, loop, session_params, https_proxy)
#      79 self.https_proxy = https_proxy  # move this to the constructor
#      81 try:
# ---> 82     await self.ping()
#      84     # calculate timestamp offset between local and binance server
#      85     res = await self.get_server_time()
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/binance/async_client.py:296, in AsyncClient.ping(self)
#     295 async def ping(self) -> Dict:
# --> 296     return await self._get("ping", version=self.PRIVATE_API_VERSION)
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/binance/async_client.py:249, in AsyncClient._get(self, path, signed, version, **kwargs)
#     246 async def _get(
#     247     self, path, signed=False, version=BaseClient.PUBLIC_API_VERSION, **kwargs
#     248 ):
# --> 249     return await self._request_api("get", path, signed, version, **kwargs)
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/binance/async_client.py:184, in AsyncClient._request_api(self, method, path, signed, version, **kwargs)
#     182 uri = self._create_api_uri(path, signed, version)
#     183 force_params = kwargs.pop("force_params", False)
# --> 184 return await self._request(method, uri, signed, force_params, **kwargs)
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/binance/async_client.py:147, in AsyncClient._request(self, method, uri, signed, force_params, **kwargs)
#     144     url_encoded_data = urlencode(dict_data)
#     145     data = f"{url_encoded_data}&signature={signature}"
# --> 147 async with getattr(self.session, method)(
#     148     yarl.URL(uri, encoded=True),
#     149     proxy=self.https_proxy,
#     150     headers=headers,
#     151     data=data,
#     152     **kwargs,
#     153 ) as response:
#     154     self.response = response
#     155     return await self._handle_response(response)
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/aiohttp/client.py:1425, in _BaseRequestContextManager.__aenter__(self)
#    1424 async def __aenter__(self) -> _RetType:
# -> 1425     self._resp: _RetType = await self._coro
#    1426     return await self._resp.__aenter__()
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/aiohttp/client.py:703, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, server_hostname, proxy_headers, trace_request_ctx, read_bufsize, auto_decompress, max_line_size, max_field_size)
#     701 # connection timeout
#     702 try:
# --> 703     conn = await self._connector.connect(
#     704         req, traces=traces, timeout=real_timeout
#     705     )
#     706 except asyncio.TimeoutError as exc:
#     707     raise ConnectionTimeoutError(
#     708         f"Connection timeout to host {url}"
#     709     ) from exc
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/aiohttp/connector.py:548, in BaseConnector.connect(self, req, traces, timeout)
#     546     for trace in traces:
#     547         await trace.send_connection_create_start()
# --> 548 proto = await self._create_connection(req, traces, timeout)
#     549 if traces:
#     550     for trace in traces:
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/aiohttp/connector.py:1056, in TCPConnector._create_connection(self, req, traces, timeout)
#    1054     _, proto = await self._create_proxy_connection(req, traces, timeout)
#    1055 else:
# -> 1056     _, proto = await self._create_direct_connection(req, traces, timeout)
#    1058 return proto
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/aiohttp/connector.py:1400, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1398 else:
#    1399     assert last_exc is not None
# -> 1400     raise last_exc
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/aiohttp/connector.py:1369, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1364 server_hostname = (
#    1365     (req.server_hostname or host).rstrip(".") if sslcontext else None
#    1366 )
#    1368 try:
# -> 1369     transp, proto = await self._wrap_create_connection(
#    1370         self._factory,
#    1371         timeout=timeout,
#    1372         ssl=sslcontext,
#    1373         addr_infos=addr_infos,
#    1374         server_hostname=server_hostname,
#    1375         req=req,
#    1376         client_error=client_error,
#    1377     )
#    1378 except (ClientConnectorError, asyncio.TimeoutError) as exc:
#    1379     last_exc = exc
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/aiohttp/connector.py:1130, in TCPConnector._wrap_create_connection(self, addr_infos, req, timeout, client_error, *args, **kwargs)
#    1128 if exc.errno is None and isinstance(exc, asyncio.TimeoutError):
#    1129     raise
# -> 1130 raise client_error(req.connection_key, exc) from exc
#
# ClientConnectorError: Cannot connect to host api.binance.com:443 ssl:default [Connect call failed ('127.0.0.1', 443)]

# %% [markdown]
# ## Use private key

# %%
key_path = os.path.expanduser('~/Desktop/Downloads/aaa/binance.private')
client = await AsyncClient(private_key=key_path)
aaa = await client.get_account()
aaa
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 key_path = os.path.expanduser('~/Desktop/Downloads/aaa/binance.private')
# ----> 2 client = await AsyncClient(private_key=key_path)
#       3 aaa = await client.get_account()
#       4 aaa
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/binance/async_client.py:44, in AsyncClient.__init__(self, api_key, api_secret, requests_params, tld, base_endpoint, testnet, loop, session_params, private_key, private_key_pass, https_proxy, time_unit)
#      42 self.loop = loop or get_loop()
#      43 self._session_params: Dict[str, Any] = session_params or {}
# ---> 44 super().__init__(
#      45     api_key,
#      46     api_secret,
#      47     requests_params,
#      48     tld,
#      49     base_endpoint,
#      50     testnet,
#      51     private_key,
#      52     private_key_pass,
#      53     time_unit=time_unit,
#      54 )
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/binance/base_client.py:199, in BaseClient.__init__(self, api_key, api_secret, requests_params, tld, base_endpoint, testnet, private_key, private_key_pass, loop, time_unit)
#     197 self.TIME_UNIT = time_unit
#     198 self._is_rsa = False
# --> 199 self.PRIVATE_KEY: Any = self._init_private_key(private_key, private_key_pass)
#     200 self.session = self._init_session()
#     201 self._requests_params = requests_params
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/binance/base_client.py:245, in BaseClient._init_private_key(self, private_key, private_key_pass)
#     243     self._is_rsa = True
#     244     return RSA.import_key(private_key, passphrase=private_key_pass)
# --> 245 return ECC.import_key(private_key)
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/Crypto/PublicKey/ECC.py:1322, in import_key(encoded, passphrase, curve_name)
#    1319         raise ValueError("No curve name was provided")
#    1320     return _import_public_der(encoded, curve_name=curve_name)
# -> 1322 raise ValueError("ECC key format is not supported")
#
# ValueError: ECC key format is not supported

# %% [markdown]
# ## Account

# %%
# status = await client.get_account_api_trading_status()
data = await client.get_trade_fee()
feedf = pd.DataFrame(data)
feedf[feedf['symbol'] == 'zrousdt'.upper()]
# Out:
#        symbol makerCommission takerCommission
# 3035  ZROUSDT           0.001           0.001

# %% [markdown]
# ## Get all Trades

# %%
async def get_trades(symbol: str, start_time: int) -> pd.DataFrame:
    tradesdf = pd.DataFrame(await client.get_my_trades(symbol=symbol.upper(), startTime=start_time))
    if tradesdf.shape[0]:
        tradesdf['time'] = pd.to_datetime(tradesdf['time'], unit='ms')
    return tradesdf


start_time = int(arrow.get('2025-03-17').int_timestamp * 1000)
await get_trades('BANANAUSDT', start_time)
# Out:
#         symbol        id    orderId  orderListId        price          qty  \
# 0   BANANAUSDT  18955159  383583165           -1  19.41000000  11.87900000
# 1   BANANAUSDT  18955160  383583165           -1  19.41000000  35.00000000
# 2   BANANAUSDT  18955161  383583165           -1  19.42000000   0.39100000
# 3   BANANAUSDT  18955162  383583165           -1  19.42000000   4.39000000
# 4   BANANAUSDT  18955163  383583165           -1  19.42000000  24.24000000
# 5   BANANAUSDT  18955164  383583165           -1  19.42000000   0.38900000
# 6   BANANAUSDT  18955165  383583165           -1  19.42000000  24.97100000
# 7   BANANAUSDT  19083159  386446134           -1  20.81000000   2.50000000
# 8   BANANAUSDT  19083160  386446134           -1  20.80000000   5.51700000
# 9   BANANAUSDT  19083161  386446134           -1  20.80000000  32.73000000
# 10  BANANAUSDT  19083162  386446134           -1  20.80000000  22.81700000
# 11  BANANAUSDT  19083163  386446134           -1  20.80000000   9.87700000
# 12  BANANAUSDT  19083164  386446134           -1  20.80000000  15.56000000
# 13  BANANAUSDT  19083165  386446134           -1  20.80000000  12.15700000
# 14  BANANAUSDT  19094587  386831406           -1  20.04000000   0.16600000
# 15  BANANAUSDT  19094588  386831406           -1  20.05000000  23.93000000
# 16  BANANAUSDT  19094589  386831406           -1  20.05000000  20.72100000
# 17  BANANAUSDT  19094590  386831406           -1  20.05000000  21.58000000
# 18  BANANAUSDT  19094591  386831406           -1  20.05000000   8.18900000
# 19  BANANAUSDT  19094592  386831406           -1  20.06000000   0.37500000
# 20  BANANAUSDT  19094593  386831406           -1  20.06000000   0.37500000
# 21  BANANAUSDT  19094594  386831406           -1  20.06000000  29.51000000
#
#         quoteQty  commission commissionAsset                    time  isBuyer  \
# 0   230.57139000  0.01187900          BANANA 2025-03-30 02:34:30.003     True
# 1   679.35000000  0.03500000          BANANA 2025-03-30 02:34:30.003     True
# 2     7.59322000  0.00039100          BANANA 2025-03-30 02:34:30.003     True
# 3    85.25380000  0.00439000          BANANA 2025-03-30 02:34:30.003     True
# 4   470.74080000  0.02424000          BANANA 2025-03-30 02:34:30.003     True
# 5     7.55438000  0.00038900          BANANA 2025-03-30 02:34:30.003     True
# 6   484.93682000  0.02497100          BANANA 2025-03-30 02:34:30.003     True
# 7    52.02500000  0.05202500            USDT 2025-04-01 05:18:10.502    False
# 8   114.75360000  0.11475360            USDT 2025-04-01 05:18:10.502    False
# 9   680.78400000  0.68078400            USDT 2025-04-01 05:18:10.502    False
# 10  474.59360000  0.47459360            USDT 2025-04-01 05:18:10.502    False
# 11  205.44160000  0.20544160            USDT 2025-04-01 05:18:10.502    False
# 12  323.64800000  0.32364800            USDT 2025-04-01 05:18:10.502    False
# 13  252.86560000  0.25286560            USDT 2025-04-01 05:18:10.502    False
# 14    3.32664000  0.00016600          BANANA 2025-04-01 10:20:40.155     True
# 15  479.79650000  0.02393000          BANANA 2025-04-01 10:20:40.155     True
# 16  415.45605000  0.02072100          BANANA 2025-04-01 10:20:40.155     True
# 17  432.67900000  0.02158000          BANANA 2025-04-01 10:20:40.155     True
# 18  164.18945000  0.00818900          BANANA 2025-04-01 10:20:40.155     True
# 19    7.52250000  0.00037500          BANANA 2025-04-01 10:20:40.155     True
# 20    7.52250000  0.00037500          BANANA 2025-04-01 10:20:40.155     True
# 21  591.97060000  0.02951000          BANANA 2025-04-01 10:20:40.155     True
#
#     isMaker  isBestMatch
# 0     False         True
# 1     False         True
# 2     False         True
# 3     False         True
# 4     False         True
# 5     False         True
# 6     False         True
# 7     False         True
# 8     False         True
# 9     False         True
# 10    False         True
# 11    False         True
# 12    False         True
# 13    False         True
# 14    False         True
# 15    False         True
# 16    False         True
# 17    False         True
# 18    False         True
# 19    False         True
# 20    False         True
# 21    False         True

# %% [markdown]
# ## Get all Orders

# %%
start_time = int(arrow.get('2025-04').int_timestamp * 1000)
ordersdf = pd.DataFrame(await client.get_all_orders(symbol='redusdt'.upper(), startTime=start_time))
if ordersdf.shape[0]:
    ordersdf['time'] = pd.to_datetime(ordersdf['time'], unit='ms')
ordersdf['time']
# Out:
# 0   2025-04-01 06:27:35.055
# Name: time, dtype: datetime64[ns]

# %%
assetdf = pd.DataFrame(await client.get_asset_details()).T
assetdf
# Out:
#            withdrawFee minWithdrawAmount withdrawStatus depositStatus  \
# AGLD              2.21              4.42           True          True
# STPT                43                86           True          True
# SCR                0.2                 4           True          True
# ATEM               2.1               4.2           True          True
# UGX                  0                 0           True          True
# ...                ...               ...            ...           ...
# 1000CHEEMS         355               710           True          True
# NZD                  0                 0           True          True
# AKRO              3091              6182           True         False
# 1000PEPPER       75000            150000           True         False
# COTI                27                54           True          True
#
#                                        depositTip
# AGLD                                          NaN
# STPT                                          NaN
# SCR                                           NaN
# ATEM                                          NaN
# UGX                                           NaN
# ...                                           ...
# 1000CHEEMS                                    NaN
# NZD                                           NaN
# AKRO        Wallet Maintenance, Deposit Suspended
# 1000PEPPER                                    NaN
# COTI                                          NaN
#
# [829 rows x 5 columns]

# %% [markdown]
# ## Orders

# %%
async def clean_orders(df_: pd.DataFrame):
    df_['time'] = pd.to_datetime(df_['time'], unit='ms')
    df_['updateTime'] = pd.to_datetime(df_['updateTime'], unit='ms')
    df_['workingTime'] = pd.to_datetime(df_['workingTime'], unit='ms')
    df_ = df_.drop(columns=['workingTime', 'selfTradePreventionMode', 'isWorking', 'orderListId'])
    df_ = df_.rename(columns={
        'clientOrderId': 'client_orderid',
        'origQty': 'amount',
        'executedQty': 'executed_amount',
        'cummulativeQuoteQty': 'cum_quote_amount',
        'timeInForce': 'time_in_force',
        'stopPrice': 'stop_price',
        'icebergQty': 'iceberg_amount',
        'origQuoteOrderQty': 'quote_amount',
        'time': 'created_at',
        'updateTime': 'updated_at',
    })
    # df_[df_['price'] == '0.00000000']
    return df_


def df_to_sql_insert(df, table_name="orders"):
    columns = ','.join(df.columns)
    insert_template = f"INSERT INTO {table_name} ({columns}) VALUES "
    values = [
        f"({','.join([repr(val) for val in row])})"
        for row in df.itertuples(index=False)
    ]
    return insert_template + ',\n'.join(values) + ";"

# %%
# basedf = pd.DataFrame(await client.get_all_orders(symbol='BANANAUSDT')).set_index('orderId')
# ordersdf = await clean_orders(basedf.copy())
# # ordersdf.loc[386446134]
# ordersdf

start_time = arrow.get('2025-04-01').int_timestamp
ordersdf = pd.DataFrame(await client.get_all_orders(symbol='BANANAUSDT', startTime=1743465600)).set_index('orderId')
ordersdf['time'] = pd.to_datetime(ordersdf['time'], unit='ms')
ordersdf['updateTime'] = pd.to_datetime(ordersdf['updateTime'], unit='ms')
ordersdf[['time', 'updateTime']]
# start_time
# Out:
#                              time              updateTime
# orderId
# 376714213 2025-03-25 22:39:45.828 2025-03-25 22:41:31.773
# 376715538 2025-03-25 22:43:03.776 2025-03-26 00:42:57.982
# 383577752 2025-03-29 22:38:17.693 2025-03-29 22:47:48.977
# 383583165 2025-03-29 22:49:37.490 2025-03-30 02:34:30.003
# 385499582 2025-03-31 17:18:08.710 2025-04-01 05:18:06.711
# 386446134 2025-04-01 05:18:10.502 2025-04-01 05:18:10.502
# 386831406 2025-04-01 10:20:40.155 2025-04-01 10:20:40.155
# 387415847 2025-04-01 16:21:50.289 2025-04-04 16:28:39.915
# 392834280 2025-04-04 16:29:49.769 2025-04-04 16:29:49.769

# %% [markdown]
# ## Request using HMAC

# %%
# API credentials
BASE_URL = "https://api.binance.com"
api_endpoint = f'{BASE_URL}/api/v3/allOrders'

# Parameters
symbol = "REDUSDT"
start_time = arrow.get("2025-04").int_timestamp * 1000
timestamp = int(time.time() * 1000)  # Current time to prevent replay attacks
params = {
    "symbol": symbol,
    "startTime": start_time,
    "timestamp": timestamp,
}
query_string = urlencode(params)
signature = hmac.new(bytes(BINANCE_SECRET, 'utf-8'), bytes(query_string, 'utf-8'), hashlib.sha256).hexdigest()
params["signature"] = signature

# # Demo for verifying the data
# params = {
#     "symbol": symbol,
#     "startTime": start_time,
#     "timestamp": timestamp,
# }
# query_string = urlencode(params)
# signature2 = hmac.new(bytes(BINANCE_SECRET, 'utf-8'), bytes(query_string, 'utf-8'), hashlib.sha256).hexdigest()
# is_valid = hmac.compare_digest(signature, signature2)
# is_valid

# Send request
headers = {"X-MBX-APIKEY": BINANCE_KEY}
# response = requests.get(
#     f"{BASE_URL}/api/v3/allOrders",
#     headers=headers,
#     params=params,
# )
# ordersdf = pd.DataFrame(response.json())
response = httpx.get(api_endpoint, headers=headers, params=params)
ordersdf = pd.DataFrame(response.json())
ordersdf['time'] = pd.to_datetime(ordersdf['time'], unit='ms')
ordersdf['updateTime'] = pd.to_datetime(ordersdf['updateTime'], unit='ms')
ordersdf[['symbol', 'time', 'updateTime']]
# Out:
#     symbol                    time              updateTime
# 0  REDUSDT 2025-04-01 06:27:35.055 2025-04-01 06:27:35.055

# %% [markdown]
# ## Request using Public Key

# %%
from cryptography.hazmat.primitives import serialization, hashes
from cryptography.hazmat.primitives.asymmetric.ed25519 import Ed25519PrivateKey
from os.path import expanduser
import base64, time
from cryptography.hazmat.primitives.serialization import load_pem_private_key, load_ssh_private_key


# Generate keys
# !openssl genpkey -algorithm ED25519 -out private.pem
# !openssl pkey -in private.pem -pubout -out public.pem

# Load Ed25519 private key (PKCS#8 format)
with open(expanduser('~/Desktop/Downloads/aaa/private.pem'), 'rb') as f:
    private_key = Ed25519PrivateKey.from_private_bytes(
        serialization.load_pem_private_key(f.read(), password=None).private_bytes(
            encoding=serialization.Encoding.Raw,
            format=serialization.PrivateFormat.Raw,
            encryption_algorithm=serialization.NoEncryption()
        )
    )

# with open(expanduser('~/Desktop/Downloads/aaa/priv2'), 'rb') as f:
#     private_key = serialization.load_ssh_private_key(f.read(), password=None)

# with open(expanduser('~/Desktop/Downloads/aaa/private.pem'), 'rb') as f:
#     private_key = load_pem_private_key(data=f.read(), password=None)


# API params
params = {
    "symbol": 'REDUSDT',
    "startTime": arrow.get("2025-04").int_timestamp * 1000,
    'timestamp': int(time.time() * 1000),  # Current time to prevent replay attacks
}
query_string = urlencode(params)

# Sign with Ed25519
# signature = private_key.sign(query_string.encode('utf-8')).hex()
# signature = base64.b64encode(private_key.sign(query_string.encode('ASCII')))
signature = base64.b64encode(private_key.sign(query_string.encode('ASCII')))
params["signature"] = signature

# Send the request
headers = {
    'X-MBX-APIKEY': BINANCE_KEY,
}

# with open(expanduser('~/Desktop/Downloads/aaa/binance.enchance_ed25519'), 'rb') as f:
#     private_key = load_pem_private_key(data=f.read(), password=None)
#
# # Sign the request
# # payload = '&'.join([f'{param}={value}' for param, value in params.items()])
# payload = urlencode(params)
# signature = base64.b64encode(private_key.sign(payload.encode('ASCII')))
# params['signature'] = signature

base_url = "https://api.binance.com"
api_endpoint = f'{base_url}/api/v3/allOrders'
response = httpx.get(
    api_endpoint,
    headers=headers,
    params=params,
)
response
# Out:
# <Response [400 Bad Request]>

# %%
# sql = df_to_sql_insert(ordersdf, 'orders')
# sql
ll = []
# for idx, row in zip(ordersdf.index, ordersdf.to_numpy()):
for row in ordersdf.itertuples(index=True):
    dd = row._asdict()
    dd['id'] = dd['Index']
    del dd['Index']
    order = Order(**dd)
    print(order)
    # dict_ = {
    #     'id': idx,
    #     'symbol': row[0],
    #     'price': row[3],
    #     'amount': row[4],
    #     'executed_amount': row[5],
    #     'cumulative_amount': row[6],
    #     'status': row[7],
    #     'time_in_force': row[8],
    #     'type': row[9],
    #     'side': row[10],
    #     'stop_price': row[11],
    #     'iceberg': row[12],
    #     'implemented_at': row[13],
    #     'quote_amount': row[15],
    #     # 'exchange_id': 1,
    # }
    # print(dict_)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/sqlalchemy/orm/clsregistry.py:516, in _class_resolver._resolve_name(self)
#     515 if rval is None:
# --> 516     rval = d[token]
#     517 else:
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/sqlalchemy/util/_collections.py:345, in PopulateDict.__missing__(self, key)
#     344 def __missing__(self, key: Any) -> Any:
# --> 345     self[key] = val = self.creator(key)
#     346     return val
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/sqlalchemy/orm/clsregistry.py:484, in _class_resolver._access_cls(self, key)
#     482             return value
# --> 484 return self.fallback[key]
#
# KeyError: 'Account'
#
# The above exception was the direct cause of the following exception:
#
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[42], line 9
#       7 dd['id'] = dd['Index']
#       8 del dd['Index']
# ----> 9 order = Order(**dd)
#      10 print(order)
#      11 # dict_ = {
#      12 #     'id': idx,
#      13 #     'symbol': row[0],
#    (...)     27 # }
#      28 # print(dict_)
#
# File <string>:4, in __init__(__pydantic_self__, **data)
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/sqlalchemy/orm/state.py:566, in InstanceState._initialize_instance(*mixed, **kwargs)
#     563 self, instance, args = mixed[0], mixed[1], mixed[2:]  # noqa
#     564 manager = self.manager
# --> 566 manager.dispatch.init(self, args, kwargs)
#     568 try:
#     569     manager.original_init(*mixed[1:], **kwargs)
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/sqlalchemy/event/attr.py:497, in _CompoundListener.__call__(self, *args, **kw)
#     495     fn(*args, **kw)
#     496 for fn in self.listeners:
# --> 497     fn(*args, **kw)
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/sqlalchemy/orm/mapper.py:4406, in _event_on_init(state, args, kwargs)
#    4404 instrumenting_mapper = state.manager.mapper
#    4405 if instrumenting_mapper:
# -> 4406     instrumenting_mapper._check_configure()
#    4407     if instrumenting_mapper._set_polymorphic_identity:
#    4408         instrumenting_mapper._set_polymorphic_identity(state)
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/sqlalchemy/orm/mapper.py:2401, in Mapper._check_configure(self)
#    2393 @util.langhelpers.tag_method_for_warnings(
#    2394     "This warning originated from the `configure_mappers()` process, "
#    2395     "which was invoked automatically in response to a user-initiated "
#    (...)   2398 )
#    2399 def _check_configure(self) -> None:
#    2400     if self.registry._new_mappers:
# -> 2401         _configure_registries({self.registry}, cascade=True)
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/sqlalchemy/orm/mapper.py:4214, in _configure_registries(registries, cascade)
#    4208     Mapper.dispatch._for_class(Mapper).before_configured()  # type: ignore # noqa: E501
#    4209     # initialize properties on all mappers
#    4210     # note that _mapper_registry is unordered, which
#    4211     # may randomly conceal/reveal issues related to
#    4212     # the order of mapper compilation
# -> 4214     _do_configure_registries(registries, cascade)
#    4215 finally:
#    4216     _already_compiling = False
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/sqlalchemy/orm/mapper.py:4255, in _do_configure_registries(registries, cascade)
#    4253 if not mapper.configured:
#    4254     try:
# -> 4255         mapper._post_configure_properties()
#    4256         mapper._expire_memoizations()
#    4257         mapper.dispatch.mapper_configured(mapper, mapper.class_)
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/sqlalchemy/orm/mapper.py:2418, in Mapper._post_configure_properties(self)
#    2415 self._log("initialize prop %s", key)
#    2417 if prop.parent is self and not prop._configure_started:
# -> 2418     prop.init()
#    2420 if prop._configure_finished:
#    2421     prop.post_instrument_class(self)
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/sqlalchemy/orm/interfaces.py:589, in MapperProperty.init(self)
#     582 """Called after all mappers are created to assemble
#     583 relationships between mappers and perform other post-mapper-creation
#     584 initialization steps.
#     585
#     586
#     587 """
#     588 self._configure_started = True
# --> 589 self.do_init()
#     590 self._configure_finished = True
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/sqlalchemy/orm/relationships.py:1656, in RelationshipProperty.do_init(self)
#    1654 self._check_conflicts()
#    1655 self._process_dependent_arguments()
# -> 1656 self._setup_entity()
#    1657 self._setup_registry_dependencies()
#    1658 self._setup_join_conditions()
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/sqlalchemy/orm/relationships.py:1868, in RelationshipProperty._setup_entity(self, _RelationshipProperty__argument)
#    1861 resolved_argument: _ExternalEntityType[Any]
#    1863 if isinstance(argument, str):
#    1864     # we might want to cleanup clsregistry API to make this
#    1865     # more straightforward
#    1866     resolved_argument = cast(
#    1867         "_ExternalEntityType[Any]",
# -> 1868         self._clsregistry_resolve_name(argument)(),
#    1869     )
#    1870 elif callable(argument) and not isinstance(
#    1871     argument, (type, mapperlib.Mapper)
#    1872 ):
#    1873     resolved_argument = argument()
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/sqlalchemy/orm/clsregistry.py:520, in _class_resolver._resolve_name(self)
#     518             rval = getattr(rval, token)
#     519 except KeyError as err:
# --> 520     self._raise_for_name(name, err)
#     521 except NameError as n:
#     522     self._raise_for_name(n.args[0], n)
#
# File ~/Dev/venv/tktor-hx1woQCX-py3.12/lib/python3.12/site-packages/sqlalchemy/orm/clsregistry.py:501, in _class_resolver._raise_for_name(self, name, err)
#     491     raise exc.InvalidRequestError(
#     492         f"When initializing mapper {self.prop.parent}, "
#     493         f'expression "relationship({self.arg!r})" seems to be '
#    (...)    498         f"['{clsarg}']] = relationship()\""
#     499     ) from err
#     500 else:
# --> 501     raise exc.InvalidRequestError(
#     502         "When initializing mapper %s, expression %r failed to "
#     503         "locate a name (%r). If this is a class name, consider "
#     504         "adding this relationship() to the %r class after "
#     505         "both dependent classes have been defined."
#     506         % (self.prop.parent, self.arg, name, self.cls)
#     507     ) from err
#
# InvalidRequestError: When initializing mapper Mapper[Taxonomy(app_taxonomy)], expression 'Account' failed to locate a name ('Account'). If this is a class name, consider adding this relationship() to the <class 'models.common_models.Taxonomy'> class after both dependent classes have been defined.

# %% [markdown]
# ## Trades

# %%
# async def trade_history():
#     # bsm = BinanceSocketManager(client)

account_trades = await client.get_account()
# traded_symbols = {balance['asset'] + "USDT" for balance in account_trades['balances']}  # Adjust for different pairs
# traded_symbols = {bal['asset']: bal for bal in account_trades['balances'] if float(bal['free'])}
# traded_symbols = [bal for bal in account_trades['balances'] if float(bal['free'])]

# Fetch trades for each symbol
# tasks = [client.get_my_trades(symbol=symbol) for symbol in traded_symbols]
# all_trades = await asyncio.gather(*tasks, return_exceptions=True)
# ic(all_trades[0])

trade_history = [bal for bal in account_trades['balances'] if float(bal['free']) > 0 or float(bal['locked']) > 0]

df = pd.DataFrame(trade_history)  # noqa
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 # async def trade_history():
#       2 #     # bsm = BinanceSocketManager(client)
# ----> 4 account_trades = await client.get_account()
#       5 # traded_symbols = {balance['asset'] + "USDT" for balance in account_trades['balances']}  # Adjust for different pairs
#       6 # traded_symbols = {bal['asset']: bal for bal in account_trades['balances'] if float(bal['free'])}
#       7 # traded_symbols = [bal for bal in account_trades['balances'] if float(bal['free'])]
#    (...)     11 # all_trades = await asyncio.gather(*tasks, return_exceptions=True)
#      12 # ic(all_trades[0])
#      14 trade_history = [bal for bal in account_trades['balances'] if float(bal['free']) > 0 or float(bal['locked']) > 0]
#
# NameError: name 'client' is not defined

# %%
df = df[(df['free'].astype(float) >= 1) | (df['locked'].astype(float) >= 1)]
# df['asset'].unique()

# %%
tasks = [client.get_my_trades(symbol=f'{symbol}USDT') for symbol in df['asset']]
trades = await asyncio.gather(*tasks, return_exceptions=True)
tradesdf = pd.concat([pd.DataFrame(trade) for trade in trades], ignore_index=True)
tradesdf['time'] = pd.to_datetime(tradesdf['time'], unit='ms')
tradesdf = tradesdf.set_index('id').sort_values(by='time').sort_values(by='id')
tradesdf
# Out:
#              symbol     orderId  orderListId        price           qty  \
# id
# 2710807     REDUSDT    36848173           -1   0.53980000  172.10000000
# 2710808     REDUSDT    36848173           -1   0.53980000   66.30000000
# 2710809     REDUSDT    36848173           -1   0.53980000   13.90000000
# 2710810     REDUSDT    36848173           -1   0.54010000    4.20000000
# 2710811     REDUSDT    36848173           -1   0.54010000   21.30000000
# ...             ...         ...          ...          ...           ...
# 39390706    ZROUSDT   845588788           -1   3.22300000  103.50000000
# 39390707    ZROUSDT   845588788           -1   3.22300000   99.81000000
# 118591245  EGLDUSDT  1910149777           -1  18.85000000    9.22000000
# 118591246  EGLDUSDT  1910149777           -1  18.85000000    0.54000000
# 118591247  EGLDUSDT  1910149777           -1  18.85000000   45.50000000
#
#                quoteQty  commission commissionAsset                    time  \
# id
# 2710807     92.89958000  0.17210000             RED 2025-03-14 16:21:05.713
# 2710808     35.78874000  0.06630000             RED 2025-03-14 16:21:05.713
# 2710809      7.50322000  0.01390000             RED 2025-03-14 16:21:05.713
# 2710810      2.26842000  0.00420000             RED 2025-03-14 16:21:05.713
# 2710811     11.50413000  0.02130000             RED 2025-03-14 16:21:05.713
# ...                 ...         ...             ...                     ...
# 39390706   333.58050000  0.10350000             ZRO 2025-03-27 06:59:30.675
# 39390707   321.68763000  0.09981000             ZRO 2025-03-27 06:59:30.675
# 118591245  173.79700000  0.00922000            EGLD 2025-03-27 12:32:15.535
# 118591246   10.17900000  0.00054000            EGLD 2025-03-27 12:32:15.535
# 118591247  857.67500000  0.04550000            EGLD 2025-03-27 12:32:15.535
#
#            isBuyer  isMaker  isBestMatch
# id
# 2710807       True    False         True
# 2710808       True    False         True
# 2710809       True    False         True
# 2710810       True    False         True
# 2710811       True    False         True
# ...            ...      ...          ...
# 39390706      True    False         True
# 39390707      True    False         True
# 118591245     True    False         True
# 118591246     True    False         True
# 118591247     True    False         True
#
# [116 rows x 12 columns]

# %%
# tradesdf['symbol'].unique()
tradesdf.columns
# Out:
# Index(['symbol', 'orderId', 'orderListId', 'price', 'qty', 'quoteQty',
#        'commission', 'commissionAsset', 'time', 'isBuyer', 'isMaker',
#        'isBestMatch'],
#       dtype='object')

# %%
tradesdf[tradesdf['isBuyer']].sample(10)
tradesdf[(tradesdf['isBuyer']) & (tradesdf['symbol'] == 'BANANAUSDT') & (tradesdf['orderId'] == 383583165)]

# %%
comm = 0.001
total = 19.41000000 * 11.87900000
# fee = total * comm
expense = total + 0.01187900
# fee
# total
expense
# Out:
# 230.58326899999997

# %%
tradesdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 116 entries, 2710807 to 118591247
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   symbol           116 non-null    object
#  1   orderId          116 non-null    int64
#  2   orderListId      116 non-null    int64
#  3   price            116 non-null    object
#  4   qty              116 non-null    object
#  5   quoteQty         116 non-null    object
#  6   commission       116 non-null    object
#  7   commissionAsset  116 non-null    object
#  8   time             116 non-null    datetime64[ns]
#  9   isBuyer          116 non-null    bool
#  10  isMaker          116 non-null    bool
#  11  isBestMatch      116 non-null    bool
# dtypes: bool(3), datetime64[ns](1), int64(2), object(6)
# memory usage: 9.4+ KB

# %% [markdown]
# ## Compute wallet

# %%
async with get_session_context() as session:
    account = await AccountSvc.get_by_email(os.getenv('DEV_EMAIL_ADMIN'), session=session)
    binance = await ExchangeSvc.get_exchange('binance', session=session)

# %%
start_time = int(arrow.get('2025-04').int_timestamp * 1000)
asset = 'XLM'
symbol = f'{asset}USDT'
tradesdf = await get_trades(symbol, start_time)


ll = []
for i in tradesdf.itertuples():
    t = i._asdict()
    # del d['Index']
    order_id = f"{binance.prefix}_{t['orderId']}"
    trade = Trade(
        id=f"{binance.prefix}_{t['id']}",
        # exchange_orderid=order_id,
        price=t['price'],
        symbol=t['symbol'],
        commission=t['commission'],
        asset=t['commissionAsset'],
        is_best_match=t['isBestMatch'],
        is_buyer=t['isBuyer'],
        is_maker=t['isMaker'],
        amount=t['qty'],
        total=t['quoteQty'],
        exchange_id=binance.id,
        order_id=order_id,
        account_id=account.id,
        created_at=t['time'].tz_localize('UTC').to_pydatetime(),
    )
    # print(trade.model_dump())
    ll.append(trade)

wallet = '0'
usdt = '16.70510797'
for trade in ll:
    # TODO: Test this if it's correct
    if trade.is_buyer:
        wallet = str(float(wallet) + float(trade.amount) - float(trade.commission))
        usdt = str(float(usdt) - float(trade.total))
    else:
        wallet = str(float(wallet) - float(trade.amount))
        usdt = str(float(usdt) + float(trade.total) - float(trade.commission))
    # print(trade.model_dump())

{
    'xlm': wallet,
    'usdt': usdt
}
# Out:
# {'xlm': '0', 'usdt': '16.70510797'}

# %%
# usdt = await client.get_asset_balance(asset='USDT')
# xlm = await client.get_asset_balance(asset='XLM')
# usdt, xlm
baldf = pd.DataFrame((await client.get_account())['balances'])
baldf
# Out:
#            asset        free      locked
# 0            BTC  0.00000000  0.00000000
# 1            LTC  0.00000000  0.00000000
# 2            ETH  0.00001030  0.00000000
# 3            NEO  0.00000000  0.00000000
# 4            BNB  0.00000084  0.00000000
# ..           ...         ...         ...
# 655      MUBARAK  0.00000000  0.00000000
# 656    BANANAS31  0.00000000  0.00000000
# 657          TUT  0.00000000  0.00000000
# 658  BROCCOLI714  0.00000000  0.00000000
# 659         BABY  0.00000000  0.00000000
#
# [660 rows x 3 columns]

# %%
# freedf = baldf[baldf['free'].astype(float) > 1]
baldf['total'] = (baldf['free'].astype(float) + baldf['locked'].astype(float)).astype(str)
# baldf
baldf[(baldf['free'].astype(float) > 1) | (baldf['locked'].astype(float) > 1)]
# freedf
# Out:
#       asset         free         locked               total
# 11     USDT  16.86640156     0.00000000         16.86640156
# 285    EGLD  55.21274000     0.00000000            55.21274
# 599     ZRO   0.00946000   418.60000000           418.60946
# 601  BANANA   0.00089400   104.74100000          104.741894
# 646     RED   0.01740000  1720.60000000  1720.6173999999999

# %%
openordersdf = pd.DataFrame(await client.get_open_orders(symbol='EGLDUSDT'))
openordersdf
# Out:
# Empty DataFrame
# Columns: []
# Index: []
